# %% [markdown]
# # FordGoBike-TripData
# ## by Ahmed Tarek
#
# ## Preliminary Wrangling
#
# > This data set includes information about individual rides made
# in a bike-sharing system covering the greater San Francisco
# Bay area.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('201902-fordgobike-tripdata.csv')
#load the data
df.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         52185  2019-02-28 17:32:10.1450  2019-03-01 08:01:55.9750
# 1         42521  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 2         61854  2019-02-28 12:13:13.2180  2019-03-01 05:24:08.1460
# 3         36490  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 4          1585  2019-02-28 23:54:18.5490  2019-03-01 00:20:44.0740
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 1              23.0                     The Embarcadero at Steuart St
# 2              86.0                           Market St at Dolores St
# 3             375.0                           Grove St at Masonic Ave
# 4               7.0                               Frank H Ogawa Plaza
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
df.shape
# Out:
# (183412, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183412 non-null  int64
#  1   start_time               183412 non-null  object
#  2   end_time                 183412 non-null  object
#  3   start_station_id         183215 non-null  float64
#  4   start_station_name       183215 non-null  object
#  5   start_station_latitude   183412 non-null  float64
#  6   start_station_longitude  183412 non-null  float64
#  7   end_station_id           183215 non-null  float64
#  8   end_station_name         183215 non-null  object
#  9   end_station_latitude     183412 non-null  float64
#  10  end_station_longitude    183412 non-null  float64
#  11  bike_id                  183412 non-null  int64
#  12  user_type                183412 non-null  object
# ...

# %%
df.drop(['start_station_longitude','start_station_latitude','end_station_latitude','end_station_longitude'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         52185  2019-02-28 17:32:10.1450  2019-03-01 08:01:55.9750
# 1         42521  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 2         61854  2019-02-28 12:13:13.2180  2019-03-01 05:24:08.1460
# 3         36490  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 4          1585  2019-02-28 23:54:18.5490  2019-03-01 00:20:44.0740
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 1              23.0                     The Embarcadero at Steuart St
# 2              86.0                           Market St at Dolores St
# 3             375.0                           Grove St at Masonic Ave
# 4               7.0                               Frank H Ogawa Plaza
#
#    end_station_id                              end_station_name  bike_id  \
# ...

# %%
df.isnull().sum()
# Out:
# duration_sec                  0
# start_time                    0
# end_time                      0
# start_station_id            197
# start_station_name          197
# end_station_id              197
# end_station_name            197
# bike_id                       0
# user_type                     0
# member_birth_year          8265
# member_gender              8265
# bike_share_for_all_trip       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.dtypes
# Out:
# duration_sec                 int64
# start_time                  object
# end_time                    object
# start_station_id           float64
# start_station_name          object
# end_station_id             float64
# end_station_name            object
# bike_id                      int64
# user_type                   object
# member_birth_year          float64
# member_gender               object
# bike_share_for_all_trip     object
# dtype: object

# %% [markdown]
# we have to change the type of start time and end time

# %%
df['start_time'] = pd.to_datetime(df['start_time'])
#converting the object datatype into datetime using to_datetime function
df['end_time'] = pd.to_datetime(df['end_time'])

# %%
df.dtypes
# Out:
# duration_sec                        int64
# start_time                 datetime64[ns]
# end_time                   datetime64[ns]
# start_station_id                  float64
# start_station_name                 object
# end_station_id                    float64
# end_station_name                   object
# bike_id                             int64
# user_type                          object
# member_birth_year                 float64
# member_gender                      object
# bike_share_for_all_trip            object
# dtype: object

# %%
df['duration_minute'] = df['duration_sec']/60
#break down the datetime into hour , day ,month,and date
df['start_date'] = df.start_time.dt.strftime('%Y-%m-%d')
df['start_hourofday'] = df.start_time.dt.strftime('%H')
df['start_dayofweek'] = df.start_time.dt.strftime('%A')
df['start_month'] = df.start_time.dt.strftime('%B')

df.head()
# Out:
#    duration_sec              start_time                end_time  \
# 0         52185 2019-02-28 17:32:10.145 2019-03-01 08:01:55.975
# 2         61854 2019-02-28 12:13:13.218 2019-03-01 05:24:08.146
# 3         36490 2019-02-28 17:54:26.010 2019-03-01 04:02:36.842
# 4          1585 2019-02-28 23:54:18.549 2019-03-01 00:20:44.074
# 5          1793 2019-02-28 23:49:58.632 2019-03-01 00:19:51.760
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 2              86.0                           Market St at Dolores St
# 3             375.0                           Grove St at Masonic Ave
# 4               7.0                               Frank H Ogawa Plaza
# 5              93.0                      4th St at Mission Bay Blvd S
#
#    end_station_id                              end_station_name  bike_id  \
# 0            13.0                Commercial St at Montgomery St     4902
# ...

# %% [markdown]
# ### What is the structure of your dataset?
#
# > it consists of start time and end time and trip duration (All that related to Time)
#    name of start and finsih stations and their id (Related to location)
#    other coulmns related to members as gender birth year user type
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > trip durations and user types and genders
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# >  each trip info and the member info and stats to know which stations and the member groups we should focus on

# %% [markdown]
# ## Univariate Exploration
#
# > In this section, investigate distributions of individual variables. If
# you see unusual points or outliers, take a deeper look to clean things up
# and prepare yourself to look at relationships between variables.

# %%
majorgender = df['member_gender'].value_counts().index
#getting the order from the largest value to smallest using value_counts index

# %%
usedcolor = sb.color_palette()[0] #chose the fisrt color of the color palette in seaborn
sb.countplot(data=df,x='member_gender',order=majorgender,color=usedcolor);

# %% [markdown]
# we can see that the most of users are men
# Now lets find out the age range of our users

# %%
ages =  2019 - df.member_birth_year
#taking the diffrence between the current year and the year they born in to get thier age

# %%
agerange = np.arange(ages.min(),70+5,5); 
#making range of values with diffrenet of 5 units to be used as x ticks
plt.hist(ages,bins=agerange);
plt.xticks(agerange,agerange);

# %% [markdown]
# It turned out the the most of users lie in range from 23 to 38 years old

# %%
sb.countplot(data=df,x='user_type',color=usedcolor);

# %% [markdown]
# We can see that most of users are male subscribers and their age is between 23 and 38
# Now lets see the most freqent stations

# %%
sstation = df.start_station_name.value_counts().index[:15] 
#taking only the largest 15 values

# %%
sb.countplot(data=df,y='start_station_name',order=sstation,color=usedcolor);

# %% [markdown]
# That was the start station
# lets check the end station as well

# %%
estation = df.end_station_name.value_counts().index[:15] 
#taking only the largest 15 values

# %%
sb.countplot(data=df,y='end_station_name',order=estation,color=usedcolor);

# %% [markdown]
# San Francicso Caltrain Station 2 and Market St are the most frequent ones
# We want now to see the trip duration and time

# %%
#list with order of the weekdays
dayorder = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']

# %%
sb.countplot(data=df,x='start_dayofweek',color=usedcolor,order=dayorder);
plt.xticks(rotation = 15);

# %% [markdown]
# It turns out that the weekend days have lower count of users compared to usual days.

# %%
df.start_hourofday.values.sort() #to sort the hours starting with 12 am

# %%
sb.countplot(data=df,x='start_hourofday',color=usedcolor);

# %% [markdown]
# Its bimodal with peaks at 8 am and 5 pm.

# %%
sb.countplot(data=df,x='duration_minute',color=usedcolor);

# %% [markdown]
# Its unreadable

# %%
plt.hist(df.duration_minute);

# %%
timerange = np.arange(0,60+3,3);
plt.hist(df.duration_minute,bins=timerange);
plt.xlim(0,60); #using xlim to zoom on the values less than 60
plt.xticks(timerange,timerange);

# %% [markdown]
# its heavily right skewed with peak at the small time intervalls

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > At first you can see that most of users are men and the age of the users are between 23 and 38
# Thursday is the day with most trips
# time was unusual as there were great outliers but the most of the trips is short
# the start and end stations with most users are almost the same
# Peak of start time was at 8 am and 5 pm whick makes sense as users go to their work school etc and come back
# there was no need for any transformations
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > Trip duration was messy and unusual at first but I changed the limit and xticks using arange so it can be clear and essy to read and understand

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, investigate relationships between pairs of variables in your
# data. Make sure the variables that you cover here have been introduced in some
# fashion in the previous section (univariate exploration).

# %%
sb.countplot(data=df,x='user_type',hue='member_gender');

# %% [markdown]
# The subscribed users are more than casual customers.
# and they are males in both cases

# %%
plt.scatter(data=df,x='member_birth_year',y='duration_minute',alpha=1/10)
plt.xlim(1940);

# %% [markdown]
# As we can see the older age have shorter trip duration than the younger age
# While you can see the younger ages have the largest outliers of long trip durations.

# %%
sb.countplot(data=df,hue='bike_share_for_all_trip' , x='user_type');

# %% [markdown]
# We see that the sibrcribes only complete full trips on bikeshare
# Also number is not very big compared to the users who dont

# %%
sb.boxplot(data=df,x='member_gender',y='duration_minute');
plt.ylim(0,60);

# %% [markdown]
# we see here that females have slightly higher trip duration than men.

# %%
sb.countplot(data=df,x='start_dayofweek',hue='user_type',order=dayorder);
plt.xticks(rotation=15);

# %% [markdown]
# we see that on all days of the week subscribers use app more than casual users

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# >  Female trip durations are slightly longer than that of males
# the number of subscriber users was much lower on the weekend days
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > people with younger ages had the most duration time
# also to see that only subscibers used bikeshare for all the trip

# %% [markdown]
# ## Multivariate Exploration
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174952 entries, 0 to 183411
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             174952 non-null  int64
#  1   start_time               174952 non-null  datetime64[ns]
#  2   end_time                 174952 non-null  datetime64[ns]
#  3   start_station_id         174952 non-null  float64
#  4   start_station_name       174952 non-null  object
#  5   end_station_id           174952 non-null  float64
#  6   end_station_name         174952 non-null  object
#  7   bike_id                  174952 non-null  int64
#  8   user_type                174952 non-null  object
#  9   member_birth_year        174952 non-null  float64
#  10  member_gender            174952 non-null  object
#  11  bike_share_for_all_trip  174952 non-null  object
#  12  duration_minute          174952 non-null  float64
# ...

# %%
g1 = sb.FacetGrid(data = df, col = 'user_type', height = 4)
g1.map(sb.boxplot, 'member_gender', 'duration_minute');
plt.ylim(0,60);

# %% [markdown]
# customer males are slightly larger than ffemales while subscribers females are larger than males

# %%
g1 = sb.FacetGrid(data = df, col = 'user_type', height = 8)
g1.map(sb.boxplot, 'start_dayofweek', 'duration_minute',order=dayorder);
plt.ylim(0,60);

# %% [markdown]
# we see duration time of customer in genral is higher than subscribers and especially on holiday days.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > it seems like the customer male users have slightly higher trip duration while the female subscriber users have slightly higher trip duration
#
# ### Were there any interesting or surprising interactions between features?
#
# > No big surprises but Its intersting the steady and nearly trip duration of the subscribes across the week,on the other hand customer vary more than subscribers and espicially on weekend days the trip duration increase for customers
