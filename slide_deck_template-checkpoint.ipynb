# %% [markdown]
# # FordGoBike-TripData
# ## by Ahmed Tarek

# %% [markdown]
# ## Investigation Overview
#
# > we are investigating about the user types ,gender and trip durations in this dataset and how they are connected to each other.
#
# ## Dataset Overview
#
# > This data set includes information about individual rides made
# in a bike-sharing system covering the greater San Francisco
# Bay area

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv('201902-fordgobike-tripdata.csv')
df.drop(['start_station_longitude','start_station_latitude','end_station_latitude','end_station_longitude'],axis=1,inplace=True)
df.dropna(inplace=True)
df['start_time'] = pd.to_datetime(df['start_time'])
df['end_time'] = pd.to_datetime(df['end_time'])
df['duration_minute'] = df['duration_sec']/60
df['start_date'] = df.start_time.dt.strftime('%Y-%m-%d')
df['start_hourofday'] = df.start_time.dt.strftime('%H')
df['start_dayofweek'] = df.start_time.dt.strftime('%A')
df['start_month'] = df.start_time.dt.strftime('%B')

# %%
dayorder = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']

# %% [markdown]
# > Note that the above cells have been set as "Skip"-type slides. That means
# that when the notebook is rendered as http slides, those cells won't show up.

# %% [markdown]
# ## Peak Time
#
# > Its found that its bimodal the peak hour where the trip duration is the longest at 8 am and at 5 pm which make sense as the most of users use bikes to go to and back from work and school.

# %%
usedcolor = sb.color_palette()[0]
df.start_hourofday.values.sort()
sb.countplot(data=df,x='start_hourofday',color=usedcolor);
plt.title('Frequency of each start hour on the day')
plt.xlabel('Start hour (24 hour format)')
plt.ylabel('Number of users on this hour');

# %% [markdown]
# ## Who uses bikeshare for all the trip?
#
# > We Found that the subrciber almost is the only who take full trips by bikeshare

# %%
sb.countplot(data=df,hue='bike_share_for_all_trip' , x='user_type');
plt.title('Using BikeShare for all the Trip')
plt.xlabel("");
plt.ylabel("Number of users");

# %% [markdown]
# ## Customer Vs subscriber Behavior
# > We found that the trip duration of the subscribes across the week is nearly the same,on the other hand customer vary more than subscribers and espicially on weekend days the trip duration increase for customers
# Also Casual customers have trip durations more than subscribers

# %%
g1 = sb.FacetGrid(data = df, col = 'user_type', height = 8,margin_titles=True)
g1.map(sb.boxplot, 'start_dayofweek', 'duration_minute',order=dayorder);
plt.ylim(0,60);
g1.fig.subplots_adjust(top=0.9)
g1.fig.suptitle('Behavior of Customers and Subscribers');

# %%
# !jupyter nbconvert slide_deck_template-checkpoint.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] WARNING | Config option `kernel_spec_manager_class` not recognized by `NbConvertApp`.
# [NbConvertApp] Converting notebook slide_deck_template-checkpoint.ipynb to slides
# [NbConvertApp] Writing 649703 bytes to slide_deck_template-checkpoint.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Traceback (most recent call last):
#   File "C:\Users\ahmed\anaconda3\Scripts\jupyter-nbconvert-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\ahmed\anaconda3\lib\site-packages\jupyter_core\application.py", line 254, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "C:\Users\ahmed\anaconda3\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\ahmed\anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 350, in start
#     self.convert_notebooks()
# ...
